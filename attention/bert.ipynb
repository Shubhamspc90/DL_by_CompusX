# %% [markdown]
# Visit the github repository for full documentation and additional use cases. Check out the blog for a deep dive on BertViz and the attention mechanism.

# %% [markdown]
# https://github.com/jessevig/bertviz
