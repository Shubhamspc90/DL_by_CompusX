# %%
from keras.layers import *
from keras.models import Model

# %%
# define two sets of inputs
inputA = Input(shape=(32,))
inputB = Input(shape=(128,))

# %%
# the first branch operated on the first input
x = Dense(8,activation='relu')(inputA)
x1=Dense(4,activation='relu')(x)

# %%
# the second brnch operates on the second input
y= Dense(64,activation='relu')(inputB)
y1 = Dense(32,activation='relu')(y)
y2 = Dense(4,activation='relu')(y1)

# %%
# combine the output of the two branches
combined = concatenate([x1,y2])

# %%
# apply a Fully Connected layer and then a regression prediction on the Combined output
z = Dense(2,activation='relu')(combined)
z1 = Dense(1,activation='linear')(z)

# %%
# our model will accept the input of the two branches and then output a single value
model = Model(inputs = [inputA,inputB], outputs = z1)

# %%
from keras.utils import plot_model
plot_model(model)
