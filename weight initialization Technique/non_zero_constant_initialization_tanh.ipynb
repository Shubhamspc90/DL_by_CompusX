# %% [markdown]
# 1. Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %% [markdown]
# 2.1 Creating Datasets

# %%
# Generate 2000 non-linear samples
X, y = make_moons(
    n_samples=2000,
    noise=0.12,
    random_state=42
)

# Create DataFrame in the same format as your image
df = pd.DataFrame({
    'X': X[:, 0],
    'Y': X[:, 1],
    'Class': y.astype(float)
})

df.head()
# Out:
#           X         Y  Class
# 0  1.750613  0.215969    1.0
# 1  0.388455  0.937320    0.0
# 2  0.494370 -0.308781    1.0
# 3 -0.947407  0.137360    0.0
# 4  0.504882 -0.348035    1.0

# %% [markdown]
# 2.2 Visualize the Dataset

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    df['X'],
    df['Y'],
    c=df['Class']
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Dataset')
plt.show()

# %% [markdown]
# 3. Separate Features and Target

# %%
X = df.iloc[:, 0:2].values
y = df.iloc[:, -1].values

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (2000, 2)
# y shape: (2000,)

# %% [markdown]
# 4. Create Neural Network with tanh

# %%
model = Sequential()

model.add(
    Dense(
        2,
        activation='tanh',
        input_shape=(2,)
    )
)

model.add(
    Dense(
        1,
        activation='sigmoid'
    )
)
# Out:
# e:\DL_by_CompusX\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# 5. Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 6. Check Initial Weights

# %%
model.get_weights()
# Out:
# [array([[-0.66549635,  0.00399339],
#         [ 0.04997814,  0.30249155]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[ 0.47546303],
#         [-0.24636853]], dtype=float32),
#  array([0.], dtype=float32)]

# %% [markdown]
# 7. Store the Weights

# %%
initial_weights = model.get_weights()

# %% [markdown]
# 8. Set All Weights and Biases to onces,and constant

# %%
initial_weights[0] = np.ones(
    model.get_weights()[0].shape
)*0.5

initial_weights[1] = np.ones(
    model.get_weights()[1].shape
)*0.5

initial_weights[2] = np.ones(
    model.get_weights()[2].shape
)*0.5

initial_weights[3] = np.ones(
    model.get_weights()[3].shape
)*0.5

# %% [markdown]
# 9. Set Zero Weights in the Model

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0.5, 0.5],
#         [0.5, 0.5]], dtype=float32),
#  array([0.5, 0.5], dtype=float32),
#  array([[0.5],
#         [0.5]], dtype=float32),
#  array([0.5], dtype=float32)]

# %% [markdown]
# 10. Compile the Model

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# 11. Train the Model

# %%
history = model.fit(
    X,
    y,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4888 - loss: 0.8318 - val_accuracy: 0.5450 - val_loss: 0.7530
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7931 - val_accuracy: 0.5450 - val_loss: 0.7240
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7612 - val_accuracy: 0.5450 - val_loss: 0.7012
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7360 - val_accuracy: 0.5450 - val_loss: 0.6836
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4919 - loss: 0.7156 - val_accuracy: 0.5550 - val_loss: 0.6694
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5063 - loss: 0.6989 - val_accuracy: 0.5850 - val_loss: 0.6574
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5531 - loss: 0.6846 - val_accuracy: 0.6100 - val_loss: 0.6469
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5925 - loss: 0.6717 - val_accuracy: 0.6550 - val_loss: 0.6361
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6325 - loss: 0.6587 - val_accuracy: 0.6975 - val_loss: 0.6248
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6625 - loss: 0.6453 - val_accuracy: 0.7225 - val_loss: 0.6126
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6900 - loss: 0.6310 - val_accuracy: 0.7375 - val_loss: 0.5988
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7119 - loss: 0.6157 - val_accuracy: 0.7525 - val_loss: 0.5837
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7231 - loss: 0.5991 - val_accuracy: 0.7625 - val_loss: 0.5681
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7269 - loss: 0.5819 - val_accuracy: 0.7575 - val_loss: 0.5519
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7300 - loss: 0.5641 - val_accuracy: 0.7550 - val_loss: 0.5353
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7287 - loss: 0.5461 - val_accuracy: 0.7450 - val_loss: 0.5188
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7387 - loss: 0.5282 - val_accuracy: 0.7475 - val_loss: 0.5028
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7513 - loss: 0.5108 - val_accuracy: 0.7500 - val_loss: 0.4871
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8763 - loss: 0.2707 - val_accuracy: 0.8925 - val_loss: 0.2486
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2705 - val_accuracy: 0.8925 - val_loss: 0.2485
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8763 - loss: 0.2703 - val_accuracy: 0.8925 - val_loss: 0.2482
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2703 - val_accuracy: 0.8925 - val_loss: 0.2480
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.2701 - val_accuracy: 0.8925 - val_loss: 0.2478
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8769 - loss: 0.2700 - val_accuracy: 0.8925 - val_loss: 0.2474
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8769 - loss: 0.2699 - val_accuracy: 0.8925 - val_loss: 0.2473
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8763 - loss: 0.2698 - val_accuracy: 0.8925 - val_loss: 0.2472
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.2698 - val_accuracy: 0.8925 - val_loss: 0.2470
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8763 - loss: 0.2696 - val_accuracy: 0.8925 - val_loss: 0.2468
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.2695 - val_accuracy: 0.8925 - val_loss: 0.2467
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2694 - val_accuracy: 0.8925 - val_loss: 0.2467
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8737 - loss: 0.2694 - val_accuracy: 0.8925 - val_loss: 0.2467
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8775 - loss: 0.2694 - val_accuracy: 0.8925 - val_loss: 0.2464
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.2692 - val_accuracy: 0.8925 - val_loss: 0.2461
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2692 - val_accuracy: 0.8925 - val_loss: 0.2460
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2692 - val_accuracy: 0.8925 - val_loss: 0.2457
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2691 - val_accuracy: 0.8925 - val_loss: 0.2458
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8769 - loss: 0.2691 - val_accuracy: 0.8925 - val_loss: 0.2456
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2688 - val_accuracy: 0.8925 - val_loss: 0.2456
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2688 - val_accuracy: 0.8925 - val_loss: 0.2456
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2687 - val_accuracy: 0.8900 - val_loss: 0.2454
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8769 - loss: 0.2687 - val_accuracy: 0.8925 - val_loss: 0.2455
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2687 - val_accuracy: 0.8925 - val_loss: 0.2452
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8763 - loss: 0.2685 - val_accuracy: 0.8925 - val_loss: 0.2451
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2684 - val_accuracy: 0.8925 - val_loss: 0.2452
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8756 - loss: 0.2685 - val_accuracy: 0.8900 - val_loss: 0.2450
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.2683 - val_accuracy: 0.8900 - val_loss: 0.2450
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2683 - val_accuracy: 0.8900 - val_loss: 0.2448
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2683 - val_accuracy: 0.8925 - val_loss: 0.2449
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2683 - val_accuracy: 0.8900 - val_loss: 0.2446

# %% [markdown]
# 12. Check the Weights After Training

# %%
model.get_weights()
# Out:
# [array([[ 0.30132535,  0.30132535],
#         [-1.4508564 , -1.4508564 ]], dtype=float32),
#  array([0.16630983, 0.16630983], dtype=float32),
#  array([[2.2440944],
#         [2.2440944]], dtype=float32),
#  array([0.13916327], dtype=float32)]

# %% [markdown]
# 13. Check the Predictions

# %%
predictions = model.predict(X, verbose=0)

predictions[:10]
# Out:
# array([[0.8543224 ],
#        [0.03182637],
#        [0.9536939 ],
#        [0.22379269],
#        [0.95997006],
#        [0.93933743],
#        [0.12626274],
#        [0.9756152 ],
#        [0.31561187],
#        [0.95276546]], dtype=float32)

# %% [markdown]
# 14. Plot Training Loss

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')

plt.legend([
    'Training Loss',
    'Validation Loss'
])

plt.show()

# %% [markdown]
# 15. Plot Accuracy

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')

plt.legend([
    'Training Accuracy',
    'Validation Accuracy'
])

plt.show()

# %% [markdown]
# 16. Decision Boundary

# %%
from mlxtend.plotting import plot_decision_regions

class MyModel:

    def __init__(self, model):
        self.model = model

    def predict(self, X):
        pred = self.model.predict(
            X,
            verbose=0
        )

        return (
            pred >= 0.5
        ).astype(int).ravel()

# %% [markdown]
# 17. Create Classifier

# %%
clf = MyModel(model)

# %% [markdown]
# 18. Plot Decision Regions

# %%
plt.figure(figsize=(8, 6))

plot_decision_regions(
    X,
    y.astype(int),
    clf=clf,
    legend=2
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Decision Boundary - Non-Zero Constant Initialization + tanh')

plt.show()
