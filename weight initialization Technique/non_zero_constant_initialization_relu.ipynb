# %% [markdown]
# 1. Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %% [markdown]
# 2.1 Creating Datasets

# %%
# Generate 2000 non-linear samples
X, y = make_moons(
    n_samples=2000,
    noise=0.12,
    random_state=42
)

# Create DataFrame in the same format as your image
df = pd.DataFrame({
    'X': X[:, 0],
    'Y': X[:, 1],
    'Class': y.astype(float)
})

df.head()
# Out:
#           X         Y  Class
# 0  1.750613  0.215969    1.0
# 1  0.388455  0.937320    0.0
# 2  0.494370 -0.308781    1.0
# 3 -0.947407  0.137360    0.0
# 4  0.504882 -0.348035    1.0

# %% [markdown]
# 2.2 Visualize the Dataset

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    df['X'],
    df['Y'],
    c=df['Class']
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Dataset')
plt.show()

# %% [markdown]
# 3. Separate Features and Target

# %%
X = df.iloc[:, 0:2].values
y = df.iloc[:, -1].values

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (2000, 2)
# y shape: (2000,)

# %% [markdown]
# 4. Create Neural Network with ReLU

# %%
model = Sequential()

model.add(
    Dense(
        2,
        activation='relu',
        input_shape=(2,)
    )
)

model.add(
    Dense(
        1,
        activation='sigmoid'
    )
)
# Out:
# e:\DL_by_CompusX\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# 5. Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 6. Check Initial Weights

# %%
model.get_weights()
# Out:
# [array([[ 0.3633368 ,  1.0469257 ],
#         [ 0.34362674, -0.37431407]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[ 0.6256231],
#         [-1.29693  ]], dtype=float32),
#  array([0.], dtype=float32)]

# %% [markdown]
# 7. Store the Weights

# %%
initial_weights = model.get_weights()

# %% [markdown]
# 8. Set All Weights and Biases to ZERO

# %%
initial_weights[0] = np.ones(
    model.get_weights()[0].shape
)*0.5

initial_weights[1] = np.ones(
    model.get_weights()[1].shape
)*0.5

initial_weights[2] = np.ones(
    model.get_weights()[2].shape
)*0.5

initial_weights[3] = np.ones(
    model.get_weights()[3].shape
)*0.5

# %% [markdown]
# 9. Set Zero Weights in the Model

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0.5, 0.5],
#         [0.5, 0.5]], dtype=float32),
#  array([0.5, 0.5], dtype=float32),
#  array([[0.5],
#         [0.5]], dtype=float32),
#  array([0.5], dtype=float32)]

# %% [markdown]
# 10. Compile the Model

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# 11. Train the Model

# %%
history = model.fit(
    X,
    y,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4888 - loss: 0.8837 - val_accuracy: 0.5450 - val_loss: 0.7840
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.8300 - val_accuracy: 0.5450 - val_loss: 0.7455
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7889 - val_accuracy: 0.5450 - val_loss: 0.7172
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7577 - val_accuracy: 0.5450 - val_loss: 0.6956
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7340 - val_accuracy: 0.5450 - val_loss: 0.6798
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7159 - val_accuracy: 0.5450 - val_loss: 0.6682
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.7018 - val_accuracy: 0.5450 - val_loss: 0.6588
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.6904 - val_accuracy: 0.5450 - val_loss: 0.6514
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.6809 - val_accuracy: 0.5450 - val_loss: 0.6449
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.6726 - val_accuracy: 0.5450 - val_loss: 0.6388
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.6650 - val_accuracy: 0.5450 - val_loss: 0.6329
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.6578 - val_accuracy: 0.5450 - val_loss: 0.6266
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.6505 - val_accuracy: 0.5450 - val_loss: 0.6201
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4888 - loss: 0.6432 - val_accuracy: 0.5450 - val_loss: 0.6131
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6794 - loss: 0.6358 - val_accuracy: 0.7475 - val_loss: 0.6056
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7131 - loss: 0.6281 - val_accuracy: 0.7525 - val_loss: 0.5982
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7206 - loss: 0.6202 - val_accuracy: 0.7475 - val_loss: 0.5900
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7231 - loss: 0.6123 - val_accuracy: 0.7625 - val_loss: 0.5817
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7256 - loss: 0.6041 - val_accuracy: 0.7650 - val_loss: 0.5736
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7275 - loss: 0.5960 - val_accuracy: 0.7600 - val_loss: 0.5653
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8737 - loss: 0.3087 - val_accuracy: 0.8900 - val_loss: 0.2839
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8737 - loss: 0.3071 - val_accuracy: 0.8900 - val_loss: 0.2822
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8731 - loss: 0.3057 - val_accuracy: 0.8900 - val_loss: 0.2808
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.3044 - val_accuracy: 0.8900 - val_loss: 0.2793
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8731 - loss: 0.3029 - val_accuracy: 0.8900 - val_loss: 0.2781
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8731 - loss: 0.3017 - val_accuracy: 0.8900 - val_loss: 0.2767
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.3005 - val_accuracy: 0.8900 - val_loss: 0.2756
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8725 - loss: 0.2993 - val_accuracy: 0.8900 - val_loss: 0.2744
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.2983 - val_accuracy: 0.8900 - val_loss: 0.2735
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 0.2973 - val_accuracy: 0.8900 - val_loss: 0.2724
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 0.2963 - val_accuracy: 0.8900 - val_loss: 0.2715
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 0.2953 - val_accuracy: 0.8900 - val_loss: 0.2704
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 0.2945 - val_accuracy: 0.8900 - val_loss: 0.2696
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 0.2935 - val_accuracy: 0.8900 - val_loss: 0.2688
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8737 - loss: 0.2927 - val_accuracy: 0.8900 - val_loss: 0.2678
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8737 - loss: 0.2920 - val_accuracy: 0.8900 - val_loss: 0.2668
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2915 - val_accuracy: 0.8900 - val_loss: 0.2667
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 0.2906 - val_accuracy: 0.8900 - val_loss: 0.2658
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8737 - loss: 0.2898 - val_accuracy: 0.8900 - val_loss: 0.2648
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8737 - loss: 0.2892 - val_accuracy: 0.8900 - val_loss: 0.2640
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2886 - val_accuracy: 0.8900 - val_loss: 0.2635
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2880 - val_accuracy: 0.8900 - val_loss: 0.2629
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.2873 - val_accuracy: 0.8900 - val_loss: 0.2621
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.2866 - val_accuracy: 0.8900 - val_loss: 0.2616
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2861 - val_accuracy: 0.8900 - val_loss: 0.2610
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2856 - val_accuracy: 0.8900 - val_loss: 0.2603
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2850 - val_accuracy: 0.8900 - val_loss: 0.2598
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2846 - val_accuracy: 0.8900 - val_loss: 0.2593
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.2841 - val_accuracy: 0.8900 - val_loss: 0.2589
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2835 - val_accuracy: 0.8900 - val_loss: 0.2581
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2832 - val_accuracy: 0.8900 - val_loss: 0.2578
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.2826 - val_accuracy: 0.8900 - val_loss: 0.2573

# %% [markdown]
# 12. Check the Weights After Training

# %%
model.get_weights()
# Out:
# [array([[ 0.38797453,  0.38797453],
#         [-1.6921368 , -1.6921368 ]], dtype=float32),
#  array([0.9305793, 0.9305793], dtype=float32),
#  array([[1.5567504],
#         [1.5567504]], dtype=float32),
#  array([-2.2138622], dtype=float32)]

# %% [markdown]
# 13. Check the Predictions

# %%
predictions = model.predict(X, verbose=0)

predictions[:10]
# Out:
# array([[0.840284  ],
#        [0.09851255],
#        [0.94821477],
#        [0.2342246 ],
#        [0.9579924 ],
#        [0.9241647 ],
#        [0.13862664],
#        [0.98469526],
#        [0.36292258],
#        [0.94693327]], dtype=float32)

# %% [markdown]
# 14. Plot Training Loss

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')

plt.legend([
    'Training Loss',
    'Validation Loss'
])

plt.show()

# %% [markdown]
# 15. Plot Accuracy

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')

plt.legend([
    'Training Accuracy',
    'Validation Accuracy'
])

plt.show()

# %% [markdown]
# 16. Decision Boundary

# %%
from mlxtend.plotting import plot_decision_regions

class MyModel:

    def __init__(self, model):
        self.model = model

    def predict(self, X):
        pred = self.model.predict(
            X,
            verbose=0
        )

        return (
            pred >= 0.5
        ).astype(int).ravel()

# %% [markdown]
# 17. Create Classifier

# %%
clf = MyModel(model)

# %% [markdown]
# 18. Plot Decision Regions

# %%
plt.figure(figsize=(8, 6))

plot_decision_regions(
    X,
    y.astype(int),
    clf=clf,
    legend=2
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Decision Boundary - Non-Zero Constant Initialization + ReLU')

plt.show()
