# %% [markdown]
# 1. Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %% [markdown]
# 2.1 Creating Datasets

# %%
# Generate 2000 non-linear samples
X, y = make_moons(
    n_samples=2000,
    noise=0.12,
    random_state=42
)

# Create DataFrame in the same format as your image
df = pd.DataFrame({
    'X': X[:, 0],
    'Y': X[:, 1],
    'Class': y.astype(float)
})

df.head()
# Out:
#           X         Y  Class
# 0  1.750613  0.215969    1.0
# 1  0.388455  0.937320    0.0
# 2  0.494370 -0.308781    1.0
# 3 -0.947407  0.137360    0.0
# 4  0.504882 -0.348035    1.0

# %% [markdown]
# 2.2 Visualize the Dataset

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    df['X'],
    df['Y'],
    c=df['Class']
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Dataset')
plt.show()

# %% [markdown]
# 3. Separate Features and Target

# %%
X = df.iloc[:, 0:2].values
y = df.iloc[:, -1].values

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (2000, 2)
# y shape: (2000,)

# %% [markdown]
# 4. Create Neural Network with ReLU

# %%
model = Sequential()

model.add(
    Dense(
        2,
        activation='relu',
        input_shape=(2,)
    )
)

model.add(
    Dense(
        1,
        activation='sigmoid'
    )
)
# Out:
# e:\DL_by_CompusX\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# 5. Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 6. Check Initial Weights

# %%
model.get_weights()
# Out:
# [array([[ 1.0350047 , -1.1232369 ],
#         [ 0.49656534, -0.91255164]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[ 0.7766069],
#         [-1.3717403]], dtype=float32),
#  array([0.], dtype=float32)]

# %% [markdown]
# 7. Store the Weights

# %%
initial_weights = model.get_weights()

# %% [markdown]
# 8. Set All Weights and Biases to ZERO

# %%
initial_weights[0] = np.zeros(
    model.get_weights()[0].shape
)

initial_weights[1] = np.zeros(
    model.get_weights()[1].shape
)

initial_weights[2] = np.zeros(
    model.get_weights()[2].shape
)

initial_weights[3] = np.zeros(
    model.get_weights()[3].shape
)

# %% [markdown]
# 9. Set Zero Weights in the Model

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([0.], dtype=float32)]

# %% [markdown]
# 10. Compile the Model

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# 11. Train the Model

# %%
history = model.fit(
    X,
    y,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5113 - loss: 0.6931 - val_accuracy: 0.4550 - val_loss: 0.6936
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6931 - val_accuracy: 0.4550 - val_loss: 0.6937
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6940
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6942
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6943
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6944
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6946
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6948
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6950
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6947
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6950
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6951
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6951
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6952
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6951
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6951
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6952
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6952
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6952
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6956
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6956
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6952
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6930 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6953
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6955
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.4550 - val_loss: 0.6954

# %% [markdown]
# 12. Check the Weights After Training

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([-0.04525676], dtype=float32)]

# %% [markdown]
# 13. Check the Predictions

# %%
predictions = model.predict(X, verbose=0)

predictions[:10]
# Out:
# array([[0.48868772],
#        [0.48868772],
#        [0.48868772],
#        [0.48868772],
#        [0.48868772],
#        [0.48868772],
#        [0.48868772],
#        [0.48868772],
#        [0.48868772],
#        [0.48868772]], dtype=float32)

# %% [markdown]
# 14. Plot Training Loss

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')

plt.legend([
    'Training Loss',
    'Validation Loss'
])

plt.show()

# %% [markdown]
# 15. Plot Accuracy

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')

plt.legend([
    'Training Accuracy',
    'Validation Accuracy'
])

plt.show()

# %% [markdown]
# 16. Decision Boundary

# %%
from mlxtend.plotting import plot_decision_regions

class MyModel:

    def __init__(self, model):
        self.model = model

    def predict(self, X):
        pred = self.model.predict(
            X,
            verbose=0
        )

        return (
            pred >= 0.5
        ).astype(int).ravel()

# %% [markdown]
# 17. Create Classifier

# %%
clf = MyModel(model)

# %% [markdown]
# 18. Plot Decision Regions

# %%
plt.figure(figsize=(8, 6))

plot_decision_regions(
    X,
    y.astype(int),
    clf=clf,
    legend=2
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Decision Boundary - Zero Initialization + ReLU')

plt.show()
